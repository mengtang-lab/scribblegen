# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
real_miou = 0.6842
ratios = [1, 2, 4, 8]
mious_aug = [0.6885, 0.6779, 0.6554, 0.6542]
mious_aug_all = [0.6981, 0.6861, 0.6578, 0.6612]
mious_pretrain = [0.6798, 0.6419, 0.6286, 0.6296]
mious_best_only = [0.6937, 0.6793, 0.6546, 0.6681]

plt.plot(ratios, mious_aug, '-bo')
plt.plot(ratios, mious_aug_all, '-ro')
plt.plot(ratios, mious_pretrain, '-go')
plt.plot(ratios, mious_best_only, '-mo')
plt.axhline(real_miou, color='k', linestyle='--')
plt.xlabel('Synthetic-to-real data ratio')
plt.ylabel('Validation mIoU')
plt.legend(['Augmented', 'Augmented All Data', 'Pretrained', 'Best Only', 'Real'])
plt.show()
